# %% [markdown]
# ## Esercizio 4

# %% [markdown]
# ### Exercise 04.1
# <span style="color:blue">
# The Molecular Dynamics (MD) code starts the simulation run from a provided spatial configuration of the $N$ particles (file: <font face="Courier">config.0</font>) and, once the simulation is finished, it writes out the final configuration (file: <font face="Courier">config.final</font>).
# 1. Improve the MD code by enabling (you should insert this option via a boolean-like variable in the input file) the **possibility** to **(re)start** reading not only a **actual** spatial configuration [$\vec{r}(t)$] file but also an **old** spatial configuration [$\vec{r}(t-dt)$] file (files: <font face="Courier">old.0</font> and <font face="Courier">old.final</font>).
# 2. Moreover, add the possibility to rescale the velocities [i.e. to correct $\vec{r}(t-dt)$] in order to match a desired temperature.
# 3. In your report, put some pictures which show that you have been able to equilibrate the thermodynamic phases at the beginning of your simulations.
#
# The typical required operations when the re-start option will be enabled are:
# 1. read $\vec{r}(t)$ and $\vec{r}(t-dt)$ from the corresponding input files
# 2. compute $\vec{r}(t+dt)$ with one step of the Verlet algorithm; with $\vec{r}(t+dt)$ and $\vec{r}(t)$ compute $\vec{v}(t+dt/2)$; finally obtain the actual temperature $T(t+dt/2)$
# 3. by comparing $T(t+dt/2)$ with the desired/target temperature  $T^\star$ extract a scaling factor for the velocities and rescale them: $\vec{v}(t) \to \vec{v}_s(t)$
# 4. use $\vec{v}_s(t)$ to estimate a novel **old** spatial configuration: $\vec{r}_{new}(t) = \vec{r}(t+dt) - dt \vec{v}_s$
# 5. use $\vec{r}_{new}(t)$ and $\vec{r}(t+dt)$ to start the simulation
# 6. Do not forget to use **periodic boundary contitions** every time it is appropriate!
#
# This will help you, especially in the equilibration phases of your simulations.
#     </span>

# %% [markdown]
# Nel grafico sottostante vengono mostrati i valori di tempertura espressi in unità di lennard-jones nel caso di un sistema solido a 108 particelle interagenti con un potenziale di tipo lennard-jones. Viene evidenziato come, dato il valore scelto per la temperatura iniziale di circa 1.4 u.l.j., essa scenda molto dopo appena pochi steps ed è necessario che la procedura di inizializzazione venga ripetuta più volte (in questo caso 4) affinché la temperatura si assesti sul valore desisderato.
# Ad ogni ripartenza il sistema evolve di 1000 step

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

file=open("4_1/es4_1_thermal.dat")
sum=0
for line in file:
    sum+=1
file.close()

temp = np.loadtxt("4_1/es4_1_thermal.dat", unpack='true')

plt.figure(figsize=(10,7))

x=np.arange(sum)
plt.plot(x,temp, 'b.')
plt.xlabel('step')
plt.ylabel('Temperature [U.L.J]')
plt.title('Thermodynamic phases equilibration: desired temperature = 1.4 u.l.j')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 04.2
# <span style="color:blue">
# The Molecular Dynamics code we have provided prints out only instantaneous values for the total (internal) energy per particle, $E/N$, potential energy per particle, $U/N$, kinetic energy per particle, $K/N$, and temperature, $T$.
# Take the MD code and include block averaging:
#
# Divide the <font face="Courier">nstep</font> of the simulation into <font face="Courier">nblocks</font>. By exploiting these blocks, code the calculation of the average values and the uncertainties for $E/N$, $U/N$, $K/N$ and $T$, that will be written in new specific output files, for example: <font face="Courier">ave_epot.out, ave_ekin.out, ave_etot.out, ave_temp.out</font></span>

# %% [markdown]
# Analisi dell'errore tramite metodo del data-blocking:
# energia totale di un solido a temperatura 1.4 u.l.j.

# %%
file=open("4_2/output_err_etot.dat")
sum=0
for line in file:
    sum+=1
file.close()

mean, error = np.loadtxt("4_2/output_err_etot.dat", usecols=(0,1), unpack='true')

plt.figure(figsize=(10,6))

x=np.arange(sum)
plt.errorbar(x,mean,yerr=error)

plt.xlabel('#blocks')
plt.ylabel('Etot')
plt.title('Energia totale')
plt.grid(True)

plt.show()

# %% [markdown]
# Analisi dell'errore tramite metodo del data-blocking:
# energia potenziale di un solido a temperatura 1.4 u.l.j.

# %%
file=open("4_2/output_err_epot.dat")
sum=0
for line in file:
    sum+=1
file.close()

mean, error = np.loadtxt("4_2/output_err_epot.dat", usecols=(0,1), unpack='true')

plt.figure(figsize=(10,6))

x=np.arange(sum)
plt.errorbar(x,mean,yerr=error)

plt.xlabel('#blocks')
plt.ylabel('Epot')
plt.title('Energia potenziale')
plt.grid(True)
plt.show()

# %% [markdown]
# Analisi dell'errore tramite metodo del data-blocking:
# energia cinetica di un solido a temperatura 1.4 u.l.j.

# %%
file=open("4_2/output_err_ekin.dat")
sum=0
for line in file:
    sum+=1
file.close()

mean, error = np.loadtxt("4_2/output_err_ekin.dat", usecols=(0,1), unpack='true')

plt.figure(figsize=(10,6))

x=np.arange(sum)
plt.errorbar(x,mean,yerr=error)

plt.xlabel('#blocks')
plt.ylabel('Ekin')
plt.title('Energia cinetica')
plt.grid(True)
plt.show()

# %% [markdown]
# Analisi dell'errore tramite metodo del data-blocking:
# temperatura del solido (temperatura iniziale di 1.4 u.l.j.)

# %%
file=open("4_2/output_err_temp.dat")
sum=0
for line in file:
    sum+=1
file.close()

mean, error = np.loadtxt("4_2/output_err_temp.dat", usecols=(0,1), unpack='true')

plt.figure(figsize=(10,6))

x=np.arange(sum)
plt.errorbar(x,mean,yerr=error)

plt.xlabel('#blocks')
plt.ylabel('Temp')
plt.title('Temperatura')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 04.3
# <span style="color:blue">
# By means of your upgraded MD code, equilibrate and perform MD simulations via a Lennard-Jones model of Argon ($\sigma = 0.34$ nm, $\epsilon/k_B = 120$ K, $m=39.948$ amu) in the following conditions:
# 1. solid phase: $\rho^\star = 1.1$, $T^\star = 0.8$ (cut-off radius: $r_c = 2.2$)
# 2. liquid phase: $\rho^\star = 0.8$, $T^\star = 1.1$ (cut-off radius: $r_c = 2.5$)
# 3. gas phase: $\rho^\star = 0.05$, $T^\star = 1.2$ (cut-off radius: $r_c = 5.0$)
#
# and show in pictures the obtained average values and uncertainties for the total (internal) energy per particle, $E/N$, the potential energy per particle, $U/N$, the kinetic energy per particle, $K/N$ and the temperature, $T$ ... in SI units!</span>

# %% [markdown]
# Di seguito sono messe a confronto alcune proprietà (temperatura, energia potenziale, energia totale ed energia cinetica) simulate per un campione di particelle di Argon interagenti tramite un potenziale di tipo Lennard-Jones. le simulazioni sono state fatte variando temperatura iniziale (solido: 0.8, liquido: 1.1, gas: 1.2 -le unità di misura sono in unità di Lennard-Jones-), densità (solido: 1.1, liquido: 0.8, gas: 0.05) e raggio di cutoff (solido: 2.2, liquido: 2.5, gas: 5.0). Nei grafici i valori sono in unità di misura S.I. Ogni step temporale equivale a circa 0.23 fs

# %%
xS, meanS, errorS = np.loadtxt("4_3/phases/output.epot.solid", usecols=(0,2,3), unpack='true')
xL, meanL, errorL = np.loadtxt("4_3/phases/output.epot.liquid", usecols=(0,2,3), unpack='true')
xG, meanG, errorG = np.loadtxt("4_3/phases/output.epot.gas", usecols=(0,2,3), unpack='true')

plt.figure(figsize=(12,7))

plt.errorbar(xS,meanS,yerr=errorS)
plt.errorbar(xL,meanL,yerr=errorL)
plt.errorbar(xG,meanG,yerr=errorG)


plt.xlabel('#blocks')
plt.ylabel('Potential energy [J/Kb]')
plt.title('Energia potenziale')
plt.grid(True)
blue_patch = mpatches.Patch(color='blue', label='Solid phase')
orange_patch = mpatches.Patch(color='orange', label='Liquid phase')
green_patch = mpatches.Patch(color='green', label='Gas phase')
plt.legend(handles=[blue_patch,orange_patch,green_patch])
plt.show()

# %%
xS, meanS, errorS = np.loadtxt("4_3/phases/output.ekin.solid", usecols=(0,2,3), unpack='true')
xL, meanL, errorL = np.loadtxt("4_3/phases/output.ekin.liquid", usecols=(0,2,3), unpack='true')
xG, meanG, errorG = np.loadtxt("4_3/phases/output.ekin.gas", usecols=(0,2,3), unpack='true')

plt.figure(figsize=(12,7))

plt.errorbar(xS,meanS,yerr=errorS)
plt.errorbar(xL,meanL,yerr=errorL)
plt.errorbar(xG,meanG,yerr=errorG)


plt.xlabel('#blocks')
plt.ylabel('Kinetic energy [J/Kb]')
plt.title('Energia cinetica')
plt.grid(True)
blue_patch = mpatches.Patch(color='blue', label='Solid phase')
orange_patch = mpatches.Patch(color='orange', label='Liquid phase')
green_patch = mpatches.Patch(color='green', label='Gas phase')
plt.legend(handles=[blue_patch,orange_patch,green_patch])
plt.show()

# %%
xS, meanS, errorS = np.loadtxt("4_3/phases/output.etot.solid", usecols=(0,2,3), unpack='true')
xL, meanL, errorL = np.loadtxt("4_3/phases/output.etot.liquid", usecols=(0,2,3), unpack='true')
xG, meanG, errorG = np.loadtxt("4_3/phases/output.etot.gas", usecols=(0,2,3), unpack='true')

plt.figure(figsize=(12,7))

plt.errorbar(xS,meanS,yerr=errorS)
plt.errorbar(xL,meanL,yerr=errorL)
plt.errorbar(xG,meanG,yerr=errorG)


plt.xlabel('#blocks')
plt.ylabel('Total energy [J/Kb]')
plt.title('Energia totale')
plt.grid(True)
blue_patch = mpatches.Patch(color='blue', label='Solid phase')
orange_patch = mpatches.Patch(color='orange', label='Liquid phase')
green_patch = mpatches.Patch(color='green', label='Gas phase')
plt.legend(handles=[blue_patch,orange_patch,green_patch])
plt.show()

# %%
xS, meanS, errorS = np.loadtxt("4_3/phases/output.temp.solid", usecols=(0,2,3), unpack='true')
xL, meanL, errorL = np.loadtxt("4_3/phases/output.temp.liquid", usecols=(0,2,3), unpack='true')
xG, meanG, errorG = np.loadtxt("4_3/phases/output.temp.gas", usecols=(0,2,3), unpack='true')

plt.figure(figsize=(12,7))

plt.errorbar(xS,meanS,yerr=errorS)
plt.errorbar(xL,meanL,yerr=errorL)
plt.errorbar(xG,meanG,yerr=errorG)


plt.xlabel('#blocks')
plt.ylabel('Temperature[K]')
plt.title('Temperatura')
plt.grid(True)
blue_patch = mpatches.Patch(color='blue', label='Solid phase')
orange_patch = mpatches.Patch(color='orange', label='Liquid phase')
green_patch = mpatches.Patch(color='green', label='Gas phase')
plt.legend(handles=[blue_patch,orange_patch,green_patch])
plt.show()

# %% [markdown]
# Di seguito sono  riportate le funzioni di correlazione radiale per il sistema di particelle nelle rispettive 3 fasi solido, liquido e gassoso

# %%
rS, gS, errS = np.loadtxt("4_3/phases/output.gofr.solid.MD", usecols=(0,1,2), unpack='true')
rL, gL, errL = np.loadtxt("4_3/phases/output.gofr.liquid.MD", usecols=(0,1,2), unpack='true')
rG, gG, errG = np.loadtxt("4_3/phases/output.gofr.gas.MD", usecols=(0,1,2), unpack='true')

fig_gofr, axs_gofr= plt.subplots(3,figsize=(10,15))

axs_gofr[0].errorbar(rS, gS, errS)
axs_gofr[1].errorbar(rL, gL, errL)
axs_gofr[2].errorbar(rG, gG, errG)
axs_gofr[0].set_title('Funzione g(r), caso solido')
axs_gofr[1].set_title('Funzione g(r), caso liquido')
axs_gofr[2].set_title('Funzione g(r), caso gassoso')
axs_gofr[0].set(xlabel='r/sigma', ylabel='g(r)')
axs_gofr[1].set(xlabel='r/sigma', ylabel='g(r)')
axs_gofr[2].set(xlabel='r/sigma', ylabel='g(r)')
axs_gofr[0].grid(True)
axs_gofr[1].grid(True)
axs_gofr[2].grid(True)

plt.show()
